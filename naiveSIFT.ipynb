# %%
# !pip install uproot
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.5/397.5 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 924.2/924.2 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.8/657.8 kB 33.5 MB/s eta 0:00:00
# ...

# %%
import naive
# Out:
# /content/naive.py:375: SyntaxWarning: invalid escape sequence '\m'
#   (2* p^{\mu}_i * p_{\mu}_j) / ((E_T^i)^2 + (E_T^j)^2)

# %%
InputJets = naive.JetReader("PythiaEventsBatchTest.root",'pdEventTree')

# %%
OutHistory_SIFT, OutJets_SIFT = naive.SIFT(InputJets)

# %%
for step in OutHistory_SIFT:
  print(step)
# Out:
# ('merge', ([132], [117]))
# ('merge', ([77], [76]))
# ('merge', ([77, 76], [74]))
# ('merge', ([122], [120]))
# ('merge', ([136], [35]))
# ('merge', ([77, 76, 74], [75]))
# ('merge', ([140], [13]))
# ('merge', ([95], [23]))
# ('merge', ([79], [28]))
# ('merge', ([111], [110]))
# ('merge', ([116], [52]))
# ('merge', ([123], [66]))
# ('merge', ([94], [82]))
# ('merge', ([77, 76, 74, 75], [85]))
# ('merge', ([77, 76, 74, 75, 85], [118]))
# ('merge', ([125], [51]))
# ('merge', ([142], [124]))
# ('merge', ([92], [24]))
# ('merge', ([137], [88]))
# ('merge', ([77, 76, 74, 75, 85, 118], [114]))
# ('merge', ([111, 110], [81]))
# ('merge', ([115], [34]))
# ('merge', ([125, 51], [141]))
# ('merge', ([77, 76, 74, 75, 85, 118, 114], [1]))
# ('merge', ([77, 76, 74, 75, 85, 118, 114, 1], [84]))
# ('merge', ([91], [78]))
# ('merge', ([94, 82], [133]))
# ('merge', ([104], [70]))
# ('merge', ([123, 66], [128]))
# ('merge', ([77, 76, 74, 75, 85, 118, 114, 1, 84], [36]))
# ...

# %%
for jet in OutJets_SIFT:
  print(jet)
# Out:
# {'id': [109, 108, 39, 126, 0, 127, 77, 76, 74, 75, 85, 118, 114, 1, 84, 36, 73, 72, 46, 33, 65, 121, 64, 86, 132, 117, 48, 54, 11, 53, 119, 69, 97, 22, 87, 49, 136, 35, 95, 23, 83, 32, 115, 34, 62, 134, 63, 12, 140, 13, 67, 135, 55, 47, 50, 116, 52, 129, 122, 120, 20, 21, 68, 96, 31, 3, 45, 8, 94, 82, 133, 10, 61, 92, 24, 44, 123, 66, 128, 37, 18, 101, 19, 98, 142, 124, 16, 139, 14, 15, 99, 100, 125, 51, 141, 103, 17, 4, 58, 2, 9, 80, 30, 107, 29, 79, 28, 138, 93, 60, 57, 112, 42, 59, 102, 91, 78, 137, 88, 130, 7, 90, 111, 110, 81, 56, 40, 43, 131, 26, 89, 25, 27, 113, 41, 38, 104, 70, 71, 105, 106, 5, 6], 'E': np.float64(13599.999999999327), 'px': np.float64(1.5042966872158559e-12), 'py': np.float64(-8.986145161316017e-13), 'pz': np.float64(6.730260793119669e-10), 'pT': 1.752260417794978e-12, 'p': 6.730283603612925e-10, 'ghost_list': [], 'phi': 5.74470539993254, 'eta': 6.644026333146993, 'm': 13599.999999999327}

# %%
naive.JetWriter("naive_SIFT.root", OutJets_SIFT, "finalJets")
