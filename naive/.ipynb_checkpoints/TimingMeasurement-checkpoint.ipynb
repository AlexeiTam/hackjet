# %%
#replaces old <TimeMeasurement.ipynb>

import naive

InputJets = naive.JetReader("PythiaEventsBatchTest.root",'pdEventTree')

# %%
##### POPULATING GHOST JETS #####

# phi bounds are obvious: 0 to 2pi
# ? How do I decide bounds of y?
# For simplicity for now, I'll settle for max, min

ymin = min([jet.y for jet in InputJets])
ymax = max([jet.y for jet in InputJets])

print(f"y_min: {ymin}")
print(f"y_max: {ymax}")
# Out:
# y_min: -8.514232250012876
# y_max: 9.136680552668757

# %%
import numpy as np
pi = float(np.pi)
pi
# Out:
# 3.141592653589793

# %%
def TimingMeasurement(inputjets, ClusterFunc, *args, **kwargs):

  """
  Measures how much time it takes to cluster a set of jets.

  returns N, time_result, dt
    with N = number of initial jets clustered (including ghosts),
    time_result = average time elapsed in seconds,
    and dt = standard deviation from five trials

  """

  t_list = []

  for count in range(5):

    print(f"Trial {count} begins...")
    start = time.perf_counter()
    ClusterFunc(*args, **kwargs)
    end = time.perf_counter()

    t_list.append(end-start)
    print(f"Trial {count} complete: reading {end-start} seconds")

  dt = statistics.stdev(t_list)
  time_result = statistics.mean(t_list)



  return len(inputjets), time_result, dt

# %%
import uproot
import fastjet

file4 = uproot.open("PythiaEventsBatchTest.root")

tree = file4['pdEventTree']

#read branches into Awkward array, then numpy arrays

E_array = tree['E'].array().to_numpy()
px_array = tree['px'].array().to_numpy()
py_array = tree['py'].array().to_numpy()
pz_array = tree['pz'].array().to_numpy()
eta_array = tree['eta'].array().to_numpy()
phi_array = tree['phi'].array().to_numpy()

InputJets_fj = [fastjet.PseudoJet(px_array[i], py_array[i], pz_array[i], E_array[i]) for i in range(len(E_array))]

# %%
len(InputJets) == len(InputJets_fj)
# Out:
# True

# %%
print(len(InputJets))
print(len(InputJets_fj))
print(len(E_array))
# Out:
# 143
# 143
# 143

# %%
import time 
import statistics

nlist = [5,6,7,8,9,10]

N_data = []
t_data = []
dt_data = []

runcount = len(nlist)

for _n in nlist:

  InputJetsGhosted = naive.GhostJetPopulator(InputJets, ymin, ymax, _n, 0, 2*pi, _n)

  n_result, t_result, dt_result = TimingMeasurement(inputjets=InputJetsGhosted, j_initial=InputJetsGhosted, ClusterFunc=naive.gen_clustering, mode=-1, R_0=0.4)

  N_data.append(n_result)
  t_data.append(t_result)
  dt_data.append(dt_result)

  print(f"{n_result} clustered in {t_result} +/- {dt_result} seconds")
# Out:
# Trial 0 begins...
# Trial 0 complete: reading 7.33879441299905 seconds
# Trial 1 begins...
# Trial 1 complete: reading 7.112923173999661 seconds
# Trial 2 begins...
# Trial 2 complete: reading 7.094241811999382 seconds
# Trial 3 begins...
# Trial 3 complete: reading 6.984413276999476 seconds
# Trial 4 begins...
# Trial 4 complete: reading 7.048789724000017 seconds
# 168 clustered in 7.115832479999517 +/- 0.13411970643995214 seconds
# Trial 0 begins...
# Trial 0 complete: reading 12.738766617998408 seconds
# Trial 1 begins...
# Trial 1 complete: reading 12.771962848999465 seconds
# Trial 2 begins...
# Trial 2 complete: reading 13.004484387000048 seconds
# Trial 3 begins...
# Trial 3 complete: reading 12.933914473998811 seconds
# Trial 4 begins...
# Trial 4 complete: reading 12.974413133999406 seconds
# 204 clustered in 12.884708292399228 +/- 0.12126935627588778 seconds
# Trial 0 begins...
# Trial 0 complete: reading 24.795242001999213 seconds
# Trial 1 begins...
# Trial 1 complete: reading 25.06401613699927 seconds
# Trial 2 begins...
# Trial 2 complete: reading 25.08475324200117 seconds
# Trial 3 begins...
# Trial 3 complete: reading 25.21558934999848 seconds
# Trial 4 begins...
# Trial 4 complete: reading 25.150162833999275 seconds
# 253 clustered in 25.06195271299948 +/- 0.16050231063662995 seconds
# Trial 0 begins...
# Trial 0 complete: reading 49.56121607899877 seconds
# Trial 1 begins...
# Trial 1 complete: reading 52.92973707499914 seconds
# Trial 2 begins...
# Trial 2 complete: reading 56.60253188899878 seconds
# Trial 3 begins...
# Trial 3 complete: reading 56.46603808399959 seconds
# Trial 4 begins...
# Trial 4 complete: reading 52.68611453700032 seconds
# 317 clustered in 53.64912753279932 +/- 2.950149108928515 seconds
# Trial 0 begins...
# Trial 0 complete: reading 105.04743005300043 seconds
# Trial 1 begins...
# Trial 1 complete: reading 103.98785192200012 seconds
# Trial 2 begins...
# Trial 2 complete: reading 106.74431526300032 seconds
# Trial 3 begins...
# Trial 3 complete: reading 98.94712718899973 seconds
# Trial 4 begins...
# Trial 4 complete: reading 100.2267804869989 seconds
# 398 clustered in 102.9907009827999 +/- 3.290281529037318 seconds
# Trial 0 begins...
# Trial 0 complete: reading 197.73361108899917 seconds
# Trial 1 begins...
# Trial 1 complete: reading 195.64531046499906 seconds
# Trial 2 begins...
# Trial 2 complete: reading 197.97780212900034 seconds
# Trial 3 begins...
# Trial 3 complete: reading 196.78304705799928 seconds
# Trial 4 begins...
# Trial 4 complete: reading 198.2045710629991 seconds
# 498 clustered in 197.2688683607994 +/- 1.0566545103869092 seconds

# %%
def GhostJetPopulator_fastjet_version(jet_input, y_min, y_max, ny, phi_min, phi_max, nphi, epsil=1e-6, version=1):
  """
  Populates a set of input jets with ghosts jets. In particular, takes jet_input set,
  and adds a series of ny*nphi many ghost jets in a uniform (y,phi) grid.

  Parameters:
      jet_input (list): List of input jets.
      y_min, y_max (float): rapidity (y) bounds of the uniform (y,phi) grid where ghost jets are populated.
      phi_min, phi_max (float): phi-bounds of the uniform (y,phi) grid where ghost jets are populated.
      ny, nphi: number of ghost jets populated along y,phi axis respectively, resulting in N = ny*nphi many ghost jets.

      epsil (float): Energy of ghost jet, by default a soft, massless jet, with E = |p|= epsil.

      version (-1 or 1): alternating between versions of ghost jet indexing.

  Returns:
      list: List of input jets with added ghost jets.

  """

  y_axis = np.linspace(y_min, y_max, ny)
  phi_axis = np.linspace(phi_min, phi_max, nphi)


  y_grid, phi_grid = np.meshgrid(y_axis, phi_axis)

  y_phi_coordinates = np.column_stack((y_grid.ravel(), phi_grid.ravel()))

  # creating soft jets, using E = |p|= epsil,
  # and obtaining p-components through y, phi with
  # pz = E*tanh(y); pT = E**2 - pz**2,
  # px = pT*cos(phi); py = pT*sin(phi)

  pz_values = epsil * np.tanh(y_grid.ravel())
  pT_values = np.sqrt(epsil**2 - pz_values**2)
  px_values = pT_values * np.cos(phi_grid.ravel())
  py_values = pT_values * np.sin(phi_grid.ravel())

  #assigns indices to ghost jets sequentially, as len(jet_input), len(jet_input)+1, len(jet_input)+2, and so on.
  #input particles in jet_input assumed to be indexed as integers, from 0, 1, 2, ..., len(jet_input)-1.

  if version == 1:
    ghost_jets = [fastjet.PseudoJet(px, py, pz, epsil) for i, (px, py, pz) in enumerate(zip(px_values.ravel(), py_values.ravel(), pz_values.ravel()))]
    # for gj in ghost_jets:
    #     print(gj)
  elif version == -1:
    ghost_jets = [fastjet.PseudoJet(px, py, pz, epsil) for i, (px, py, pz) in enumerate(zip(px_values.ravel(), py_values.ravel(), pz_values.ravel()))]
  else:
    raise ValueError("Invalid version value. Must be -1 or 1.")
  #alternate possibility: index as negative numbers [i+len(jet_input)] --> [-(i+1)] (as i starts at 0), so one can more easily distinguish ghost jets by index


  jet_input += ghost_jets

  return jet_input

  jet_input += ghost_jets

  return jet_input

#!!!! key edit: on ghost_jets lines; needed to change "fastjet.PseudoJet(px,py,pz,E)" -> "fastjet.PseudoJet(px,py,pz,epsil)"

# %%
antikt_jetdef = fastjet.JetDefinition(fastjet.antikt_algorithm, 0.4)

# %%
def do_fj_clustering(inputjetset, jetdef):
    _cluster = fastjet.ClusterSequence(inputjetset, jetdef)

# %%
nlist = [5,6,7,8,9,10]

N_fj_data = []
t_fj_data = []
dt_fj_data = []

runcount = len(nlist)

#just comparing antikt:

for _n in nlist:

  InputJetsGhosted_fj = GhostJetPopulator_fastjet_version(InputJets_fj, ymin, ymax, _n, 0, 2*pi, _n)
    
  n_result, t_result, dt_result = TimingMeasurement(InputJetsGhosted_fj, do_fj_clustering, inputjetset=InputJetsGhosted_fj, jetdef=antikt_jetdef)

  N_fj_data.append(n_result)
  t_fj_data.append(t_result)
  dt_fj_data.append(dt_result)

  print(f"{n_result} clustered in {t_result} +/- {dt_result} seconds")
# Out:
# Trial 0 begins...
# Trial 0 complete: reading 0.0008379569990211166 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.00020163299996056594 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.00015739199989184272 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.00015226899995468557 seconds
# Trial 4 begins...
# Trial 4 complete: reading 0.0002128470005118288 seconds
# 168 clustered in 0.00031241959986800795 +/- 0.00029498292432663737 seconds
# Trial 0 begins...
# Trial 0 complete: reading 0.00022692800121149048 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.000193472998944344 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.00020133900034124963 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.00020677300017268863 seconds
# Trial 4 begins...
# Trial 4 complete: reading 0.0002061970008071512 seconds
# 204 clustered in 0.00020694200029538478 +/- 1.237771610372744e-05 seconds
# #--------------------------------------------------------------------------
# #                         FastJet release 3.5.1
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           https://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# Trial 0 begins...
# Trial 0 complete: reading 0.00030689699997310527 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.00025176399867632426 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.00024135799867508467 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.00023850900106481276 seconds
# Trial 4 begins...
# Trial 4 complete: reading 0.00023637300000700634 seconds
# 253 clustered in 0.00025498019967926664 +/- 2.9617523213800886e-05 seconds
# Trial 0 begins...
# Trial 0 complete: reading 0.0004657080007746117 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.0003772710006160196 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.00033219299984921236 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.00033423099921492394 seconds
# Trial 4 begins...
# Trial 4 complete: reading 0.00037717499981226865 seconds
# 317 clustered in 0.0003773156000534073 +/- 5.4096141593912815e-05 seconds
# Trial 0 begins...
# Trial 0 complete: reading 0.0004906630001642043 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.0004423119989951374 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.0004350559993326897 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.0004197870002826676 seconds
# Trial 4 begins...
# Trial 4 complete: reading 0.0004169350013398798 seconds
# 398 clustered in 0.00044095060002291575 +/- 2.971771099166469e-05 seconds
# Trial 0 begins...
# Trial 0 complete: reading 0.00069811700086575 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.0006083520001993747 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.001174705001176335 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.0010880879999604076 seconds
# Trial 4 begins...
# Trial 4 complete: reading 0.001384724000672577 seconds
# 498 clustered in 0.0009907972005748888 +/- 0.0003280213153113632 seconds

# %%
len(InputJets) == len(InputJets_fj)
# Out:
# True

# %%
import pandas as pd

tvNdf = pd.DataFrame({
    "t": t_data,
    "dt": dt_data,
    "N": N_data
})

tvNdf.to_csv('timing_data_naive.csv')

tvNdf_fj = pd.DataFrame({
    "t": t_fj_data,
    "dt": dt_fj_data,
    "N": N_fj_data
})

tvNdf.to_csv('timing_data_fj.csv')
