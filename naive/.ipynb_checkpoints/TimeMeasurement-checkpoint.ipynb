# %%
#bringing in dependencies...

#note to self: have <naive.py>, <PythiaEventsBatchTest.root> on hand!

# !pip install uproot

import naive

InputJets = naive.JetReader("PythiaEventsBatchTest.root",'pdEventTree')
# Out:
# Requirement already satisfied: uproot in /home/atam/uproot-env/lib/python3.12/site-packages (5.7.5)
# Requirement already satisfied: awkward>=2.8.2 in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2.10.0)
# Requirement already satisfied: cramjam>=2.5.0 in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2.11.0)
# Requirement already satisfied: fsspec!=2026.2.0 in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2026.6.0)
# Requirement already satisfied: numpy in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2.5.1)
# Requirement already satisfied: packaging in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (26.2)
# Requirement already satisfied: xxhash in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (3.8.1)
# Requirement already satisfied: awkward-cpp==54 in /home/atam/uproot-env/lib/python3.12/site-packages (from awkward>=2.8.2->uproot) (54)

# %%
##### POPULATING GHOST JETS #####

# phi bounds are obvious: 0 to 2pi
# ? How do I decide bounds of y?
# For simplicity for now, I'll settle for max, min

ymin = min([jet.y for jet in InputJets])
ymax = max([jet.y for jet in InputJets])

print(f"y_min: {ymin}")
print(f"y_max: {ymax}")
# Out:
# y_min: -8.514232250012876
# y_max: 9.136680552668757

# %%
import numpy as np
pi = float(np.pi)
pi
# Out:
# 3.141592653589793

# %%
import time
import statistics

def TimingMeasurement(inputjets, ClusterFunc, *args, **kwargs):

  """
  Measures how much time it takes to cluster a set of jets.

  returns N, time_result, dt
    with N = number of initial jets clustered (including ghosts),
    time_result = average time elapsed in seconds,
    and dt = standard deviation from five trials

  """

  t_list = []

  for count in range(5):

    print(f"Trial {count} begins...")
    start = time.perf_counter()
    outhistory, outjets = ClusterFunc(*args, **kwargs)
    end = time.perf_counter()

    t_list.append(end-start)
    print(f"Trial {count} complete: reading {end-start} seconds")

  dt = statistics.stdev(t_list)
  time_result = statistics.mean(t_list)



  return len(inputjets), time_result, dt

# %%
# How many ghost jets do you want? N, with N = ny*nphi

ny = 10
nphi = 10

N = ny*nphi

print(f"N: {N}")
# Out:
# N: 100

# %%
### Bringing in time module, testing it out...

# %%
print(f"Populating {N} ghost jets...")

import time

print("time test:")

start1 = time.perf_counter_ns()
InputJetsGhost = naive.GhostJetPopulator(InputJets, ymin, ymax, ny, 0, 2*pi, nphi)
end1 = time.perf_counter_ns()

print(f"Completed in {end1-start1} nanoseconds, or {(end1-start1)*(10**(-9))} s")
# Out:
# Populating 100 ghost jets...
# time test:
# Completed in 893294 nanoseconds, or 0.0008932940000000001 s

# %%
### just gonna test how this workflow goes,
### then replicate it in a callable function

t_data = []
N_data = []

start = time.perf_counter_ns()
outhistory_test, outjets_test = naive.gen_clustering(-1, InputJets, 0.4)
end = time.perf_counter_ns()

t_data.append((end-start)*(10**(-9))) #take result in nanosecs, convert to seconds
N_data.append(N)

print(f"Clustered {N} initial jets -- Completed in {end-start} nanoseconds, or {(end-start)*(10**(-9))} s")
# Out:
# Clustered 100 initial jets -- Completed in 23864914635 nanoseconds, or 23.864914635 s

# %%
help(naive.gen_clustering)
# Out:
# Help on function gen_clustering in module naive:
#
# gen_clustering(mode, j_initial, R_0, thresholding=False, pT_threshold=0.0, eta_threshold=0.0)
#     Function for clustering an input set of jets, using anti-kT clustering algorithm,
#     to return a set of final-state jets.
#
#     Parameters:
#       mode: The clustering mode to use.
#         1: kT-algorithm
#         0: Cambridge-Aachen
#         (-1): anti-kT algorithm
#
#       j_initial: List of initial jets,
#       R_0: the jet radius parameter,
#
#       thresholding: Boolean, configurable by user in case they wish to apply jet pT and eta thresholds; off by default
#       pT_threshold: minimum jet pT,
#       eta_threshold: minimum jet eta,
#
#     Returns: clustering_history, final_jets
#
#       clustering_history: list of tuples--('final'/'merge', ids of jets being promoted)
#       final_jets: List of final-state jets

# %%
n_res, t_res, dt_res = TimingMeasurement(inputjets=InputJets, j_initial=InputJets, ClusterFunc=naive.gen_clustering, mode=-1, R_0=0.4)
# Out:
# Trial 0 begins...
# Trial 0 complete: reading 24.091520564999996 seconds
# Trial 1 begins...
# Trial 1 complete: reading 23.424639834999994 seconds
# Trial 2 begins...
# Trial 2 complete: reading 23.342096920000017 seconds
# Trial 3 begins...
# Trial 3 complete: reading 23.52729478499998 seconds
# Trial 4 begins...
# Trial 4 complete: reading 23.709233917000006 seconds

# %%
print(f"N: {n_res} jets clustered")
print(f"Time: {t_res} +/- {dt_res} seconds")
# Out:
# N: 243 jets clustered
# Time: 23.618957204399997 +/- 0.29760664932015085 seconds

# %%
##### Now to do this for a wider spectrum of N #####


#collecting N,t,dt data using TimingMeasurement
# need to input:
# InputJets -- list of real input InputJets
# ny, nphi -- linear density of ghost jets in y and phi directions respectively
# for now just letting ny = nphi

nlist = [5,6,7,8,9,10]

N_data = []
t_data = []
dt_data = []

runcount = len(nlist)

for _n in nlist:

  InputJetsGhosted = naive.GhostJetPopulator(InputJets, ymin, ymax, _n, 0, 2*pi, _n)

  n_result, t_result, dt_result = TimingMeasurement(inputjets=InputJetsGhosted, j_initial=InputJetsGhosted, ClusterFunc=naive.gen_clustering, mode=-1, R_0=0.4)

  N_data.append(n_result)
  t_data.append(t_result)
  dt_data.append(dt_result)

  print(f"{n_result} clustered in {t_result} +/- {dt_result} seconds")
# Out:
# Trial 0 begins...
# Trial 0 complete: reading 31.601948473999983 seconds
# Trial 1 begins...
# Trial 1 complete: reading 31.215679739999985 seconds
# Trial 2 begins...
# Trial 2 complete: reading 33.018794497000044 seconds
# Trial 3 begins...
# Trial 3 complete: reading 33.89783768599989 seconds
# Trial 4 begins...
# Trial 4 complete: reading 33.557859908999944 seconds
# 268 clustered in 32.658424061199966 +/- 1.190866246829428 seconds
# Trial 0 begins...
# Trial 0 complete: reading 47.64898364399994 seconds
# Trial 1 begins...
# Trial 1 complete: reading 46.72460827400005 seconds
# Trial 2 begins...
# Trial 2 complete: reading 46.12819121299992 seconds
# Trial 3 begins...
# Trial 3 complete: reading 49.02924578 seconds
# Trial 4 begins...
# Trial 4 complete: reading 48.489778195999975 seconds
# 304 clustered in 47.60416142139998 +/- 1.2009676647815872 seconds
# Trial 0 begins...
# Trial 0 complete: reading 78.31792455100003 seconds
# Trial 1 begins...
# Trial 1 complete: reading 75.59078286299996 seconds
# Trial 2 begins...
# Trial 2 complete: reading 73.92674867200014 seconds
# Trial 3 begins...
# Trial 3 complete: reading 73.32500430999994 seconds
# Trial 4 begins...
# Trial 4 complete: reading 74.178010223 seconds
# 353 clustered in 75.06769412380001 +/- 1.9979915799010939 seconds
# Trial 0 begins...
# Trial 0 complete: reading 124.57204566600012 seconds
# Trial 1 begins...
# Trial 1 complete: reading 112.95733051000002 seconds
# Trial 2 begins...
# Trial 2 complete: reading 114.0562762730001 seconds
# Trial 3 begins...
# Trial 3 complete: reading 124.46082894699998 seconds
# Trial 4 begins...
# Trial 4 complete: reading 121.32789952200005 seconds
# 417 clustered in 119.47487618360006 +/- 5.615028579233534 seconds
# Trial 0 begins...
# Trial 0 complete: reading 196.38364421799997 seconds
# Trial 1 begins...
# Trial 1 complete: reading 198.43090393700004 seconds
# Trial 2 begins...
# Trial 2 complete: reading 212.9330195540001 seconds
# Trial 3 begins...
# Trial 3 complete: reading 209.01872462099982 seconds
# Trial 4 begins...
# Trial 4 complete: reading 206.63195718099996 seconds
# 498 clustered in 204.67964990219997 +/- 7.046767347254344 seconds
# Trial 0 begins...
# Trial 0 complete: reading 368.30648397999994 seconds
# Trial 1 begins...
# Trial 1 complete: reading 352.57051794200015 seconds
# Trial 2 begins...
# Trial 2 complete: reading 341.081734802 seconds
# Trial 3 begins...
# Trial 3 complete: reading 395.17577320999953 seconds
# Trial 4 begins...
# Trial 4 complete: reading 353.5408103509999 seconds
# 598 clustered in 362.1350640569999 +/- 20.846818084947646 seconds

# %%
import pandas as pd

tvNdf = pd.DataFrame({
    "t": t_data,
    "dt": dt_data,
    "N": N_data
})

tvNdf.to_csv('timing_data.csv')

# %%
import fastjet as fj
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import fastjet as fj
#
# ModuleNotFoundError: No module named 'fastjet'
