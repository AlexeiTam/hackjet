# %%
# !pip install uproot
# Out:
# Requirement already satisfied: uproot in /home/atam/uproot-env/lib/python3.12/site-packages (5.7.5)
# Requirement already satisfied: awkward>=2.8.2 in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2.10.0)
# Requirement already satisfied: cramjam>=2.5.0 in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2.11.0)
# Requirement already satisfied: fsspec!=2026.2.0 in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2026.6.0)
# Requirement already satisfied: numpy in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2.5.1)
# Requirement already satisfied: packaging in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (26.2)
# Requirement already satisfied: xxhash in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (3.8.1)
# Requirement already satisfied: awkward-cpp==54 in /home/atam/uproot-env/lib/python3.12/site-packages (from awkward>=2.8.2->uproot) (54)

# %%
import naive

# %%
InputJets = naive.JetReader("PythiaEventsBatchTest.root",'pdEventTree')

# %%
OutHistory_SIFT, OutJets_SIFT = naive.SIFT(InputJets)

# %%
for step in OutHistory_SIFT:
  print(step)

# %%
for jet in OutJets_SIFT:
  print(jet)
# Out:
# {'id': [112], 'E': np.float64(118.30118704525283), 'px': np.float64(-0.08713061133636128), 'py': np.float64(0.08699652102408609), 'pz': np.float64(-118.30104063951804), 'pT': 0.12312651258824113, 'p': 118.30110471390789, 'ghost_list': [], 'phi': 2.3569645613693746, 'eta': -7.560922913515813, 'm': 0.13956999998655878}
# {'id': [107], 'E': np.float64(23.927245621987772), 'px': np.float64(0.08608667369235393), 'py': np.float64(0.0657498076735345), 'pz': np.float64(23.926593349606556), 'pT': 0.10832337050018614, 'p': 23.926838555689574, 'ghost_list': [], 'phi': 0.6522513352183891, 'eta': 6.090777191648981, 'm': 0.1395699999995916}
# {'id': [127], 'E': np.float64(152.5131938535541), 'px': np.float64(0.03175980045072676), 'py': np.float64(-0.0559185639441752), 'pz': np.float64(152.51311643283725), 'pT': 0.06430840316979418, 'p': 152.5131299909188, 'ghost_list': [], 'phi': 5.228920378724327, 'eta': 8.464462796097694, 'm': 0.13956999992139474}
# {'id': [136, 95], 'E': np.float64(0.05943571217733644), 'px': np.float64(-0.0010252967098109689), 'py': np.float64(-0.025377957384956025), 'pz': np.float64(-0.04789257335093602), 'pT': 0.025398660483887597, 'p': 0.054210612766787465, 'ghost_list': [], 'phi': 4.672009867352415, 'eta': -1.3912874947589864, 'm': 0.02436828564910956}
# {'id': [116], 'E': np.float64(0.023294732380225815), 'px': np.float64(0.013696821743993462), 'py': np.float64(-0.003981014069439178), 'pz': np.float64(0.018417197337231784), 'pT': 0.014263639048566982, 'p': 0.02329473238022584, 'ghost_list': [], 'phi': 6.000326203656299, 'eta': 1.0730735970652805, 'm': 0.0}

# %%
naive.JetWriter("naive_SIFT.root", OutJets_SIFT, "finalJets")

# %%
print(len(OutJets_SIFT))
# Out:
# 5
