# %%
# !pip install uproot
# Out:
# Requirement already satisfied: uproot in /home/atam/uproot-env/lib/python3.12/site-packages (5.7.5)
# Requirement already satisfied: awkward>=2.8.2 in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2.10.0)
# Requirement already satisfied: cramjam>=2.5.0 in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2.11.0)
# Requirement already satisfied: fsspec!=2026.2.0 in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2026.6.0)
# Requirement already satisfied: numpy in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (2.5.1)
# Requirement already satisfied: packaging in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (26.2)
# Requirement already satisfied: xxhash in /home/atam/uproot-env/lib/python3.12/site-packages (from uproot) (3.8.1)
# Requirement already satisfied: awkward-cpp==54 in /home/atam/uproot-env/lib/python3.12/site-packages (from awkward>=2.8.2->uproot) (54)

# %%
import naive

# %%
InputJets = naive.JetReader("PythiaEventsBatchTest.root",'pdEventTree')

# %%
OutHistory_SIFT, OutJets_SIFT = naive.SIFT(InputJets)

# %%
for step in OutHistory_SIFT:
  print(step)

# %%
for jet in OutJets_SIFT:
  print(jet)
# Out:
# {'id': [77, 76, 74, 75], 'E': np.float64(11.144202025341631), 'px': np.float64(1.1356612293282753), 'py': np.float64(5.852093331830698), 'pz': np.float64(-9.405822597458075), 'pT': 5.961268555622765, 'p': 11.135808076969973, 'ghost_list': [], 'phi': 1.3791181166098339, 'eta': -1.2371702882034044, 'm': 0.4324549161691139}
# {'id': [111, 110, 56, 40, 26, 25], 'E': np.float64(200.05660373817986), 'px': np.float64(2.0175616049796488), 'py': np.float64(-2.865784250461217), 'pz': np.float64(-200.0162434701267), 'pT': 3.504750233622878, 'p': 200.04694680524642, 'ghost_list': [], 'phi': 5.325806013882645, 'eta': -4.73750325239414, 'm': 1.9656482783115934}
# {'id': [122, 120, 20, 123, 66, 128, 68, 47, 50], 'E': np.float64(9.447441460214446), 'px': np.float64(-0.1493604082562774), 'py': np.float64(-3.320638970350115), 'pz': np.float64(8.288520485568597), 'pT': 3.3239963452089345, 'p': 8.93020288362211, 'ghost_list': [], 'phi': 4.66743985896249, 'eta': 1.6448295822584853, 'm': 3.0831196216699412}
# {'id': [134, 96, 52, 141, 51, 21, 19], 'E': np.float64(20.340316955822352), 'px': np.float64(2.9602624891099323), 'py': np.float64(1.0782695253551626), 'pz': np.float64(19.91627981735768), 'pT': 3.150526808922752, 'p': 20.16392870789395, 'ghost_list': [], 'phi': 0.349311052373705, 'eta': 2.54331297970672, 'm': 2.6729146874310143}
# {'id': [94, 82, 133, 10, 46, 23, 31], 'E': np.float64(11.054122366116287), 'px': np.float64(-2.363970078955721), 'py': np.float64(-1.552207730716885), 'pz': np.float64(-10.46179188007951), 'pT': 2.82802110556042, 'p': 10.837287147418063, 'ghost_list': [], 'phi': 3.7226009922490744, 'eta': -2.0190866225589956, 'm': 2.1787217742244165}
# {'id': [91, 78, 137, 88, 90], 'E': np.float64(230.1190276568225), 'px': np.float64(-1.3673240281440686), 'py': np.float64(0.024051612393441724), 'pz': np.float64(-230.1139764653643), 'pT': 1.3675355490804786, 'p': 230.11803996684012, 'ghost_list': [], 'phi': 3.124004187584648, 'eta': -5.818720495225395, 'm': 0.6742192085843748}
# {'id': [58, 9, 44], 'E': np.float64(39.81283618607081), 'px': np.float64(0.6262779152687382), 'py': np.float64(1.1657437529168337), 'pz': np.float64(-39.78360258188096), 'pT': 1.323322532347266, 'p': 39.80560534544932, 'ghost_list': [], 'phi': 1.0778065794246354, 'eta': -4.096732860812842, 'm': 0.7587544143171994}
# {'id': [126, 0], 'E': np.float64(1804.5774573682938), 'px': np.float64(-0.2848405628459379), 'py': np.float64(1.0612869683899766), 'pz': np.float64(1804.5770667524512), 'pT': 1.0988467479666024, 'p': 1804.5774013084215, 'ghost_list': [], 'phi': 1.8330084894444814, 'eta': 8.09696758562187, 'm': 0.4498096938067902}
# {'id': [104, 70, 71, 38], 'E': np.float64(304.4905178193253), 'px': np.float64(-0.3090903334012375), 'py': np.float64(0.830462516009432), 'pz': np.float64(304.48583218342856), 'pT': 0.8861178390591199, 'p': 304.48712157537915, 'ghost_list': [], 'phi': 1.9271016801743586, 'eta': 6.532679191844162, 'm': 1.4381365099114847}
# {'id': [113, 5], 'E': np.float64(2274.0942569365043), 'px': np.float64(0.8478452085254673), 'py': np.float64(-0.0655485601318759), 'pz': np.float64(-2274.093983846574), 'pT': 0.8503752767778208, 'p': 2274.0941428413407, 'ghost_list': [], 'phi': 6.206026849149557, 'eta': -8.584561743561057, 'm': 0.7203653934694758}
# {'id': [106], 'E': np.float64(226.11594292475226), 'px': np.float64(0.8186802001518796), 'py': np.float64(-0.1782999860933424), 'pz': np.float64(226.11244385482578), 'pT': 0.8378712043993443, 'p': 226.11399623675865, 'ghost_list': [], 'phi': 6.068744388127242, 'eta': 6.29107391238716, 'm': 0.9382700000091865}
# {'id': [6], 'E': np.float64(2629.637914436583), 'px': np.float64(-0.1925606709964253), 'py': np.float64(0.4421995072783569), 'pz': np.float64(-2629.6377028160696), 'pT': 0.482306973049131, 'p': 2629.6377470465, 'ghost_list': [], 'phi': 1.9814941243412916, 'eta': -9.296923043171022, 'm': 0.9382699978262519}
# {'id': [102], 'E': np.float64(50.298572112478695), 'px': np.float64(-0.214903182930612), 'py': np.float64(-0.23876243485861076), 'pz': np.float64(50.28876985859751), 'pT': 0.3212333705163902, 'p': 50.28979583145391, 'ghost_list': [], 'phi': 3.9795345622423586, 'eta': 5.746526579294993, 'm': 0.9395700000003971}
# {'id': [39], 'E': np.float64(2488.94851357057), 'px': np.float64(-0.21158194902396202), 'py': np.float64(-0.09062833904545972), 'pz': np.float64(2488.948325585115), 'pT': 0.23017475315706817, 'p': 2488.948336228248, 'ghost_list': [], 'phi': 3.546286218572238, 'eta': 9.981679185958216, 'm': 0.9395700003316918}

# %%
naive.JetWriter("naive_SIFT.root", OutJets_SIFT, "finalJets")

# %%
print(len(OutJets_SIFT))
# Out:
# 14
