# %%
#replaces old <TimeMeasurement.ipynb>

import naive

InputJets = naive.JetReader("PythiaEventsBatchTest.root",'pdEventTree')

# %%
##### POPULATING GHOST JETS #####

# phi bounds are obvious: 0 to 2pi
# ? How do I decide bounds of y?
# For simplicity for now, I'll settle for max, min

ymin = min([jet.y for jet in InputJets])
ymax = max([jet.y for jet in InputJets])

print(f"y_min: {ymin}")
print(f"y_max: {ymax}")
# Out:
# y_min: -8.514232250012876
# y_max: 9.136680552668757

# %%
import numpy as np
pi = float(np.pi)
pi
# Out:
# 3.141592653589793

# %%
def TimingMeasurement(inputjets, ClusterFunc, *args, **kwargs):

  """
  Measures how much time it takes to cluster a set of jets.

  returns N, time_result, dt
    with N = number of initial jets clustered (including ghosts),
    time_result = average time elapsed in seconds,
    and dt = standard deviation from five trials

  """

  t_list = []

  for count in range(5):

    print(f"Trial {count} begins...")
    start = time.perf_counter()
    ClusterFunc(*args, **kwargs)
    end = time.perf_counter()

    t_list.append(end-start)
    print(f"Trial {count} complete: reading {end-start} seconds")

  dt = statistics.stdev(t_list)
  time_result = statistics.mean(t_list)



  return len(inputjets), time_result, dt

# %%
import uproot
import fastjet

file4 = uproot.open("PythiaEventsBatchTest.root")

tree = file4['pdEventTree']

#read branches into Awkward array, then numpy arrays

E_array = tree['E'].array().to_numpy()
px_array = tree['px'].array().to_numpy()
py_array = tree['py'].array().to_numpy()
pz_array = tree['pz'].array().to_numpy()
eta_array = tree['eta'].array().to_numpy()
phi_array = tree['phi'].array().to_numpy()

InputJets_fj = [fastjet.PseudoJet(px_array[i], py_array[i], pz_array[i], E_array[i]) for i in range(len(E_array))]

# %%
len(InputJets) == len(InputJets_fj)
# Out:
# True

# %%
print(len(InputJets))
print(len(InputJets_fj))
print(len(E_array))
# Out:
# 143
# 143
# 143

# %%
import time 
import statistics

nlist = [i for i in range(5,11)]

N_data = []
t_data = []
dt_data = []

runcount = len(nlist)

for _n in nlist:

  InputJetsGhosted = naive.GhostJetPopulator(InputJets, ymin, ymax, _n, 0, 2*pi, _n)

  n_result, t_result, dt_result = TimingMeasurement(inputjets=InputJetsGhosted, j_initial=InputJetsGhosted, ClusterFunc=naive.gen_clustering, mode=-1, R_0=0.4)

  N_data.append(n_result)
  t_data.append(t_result)
  dt_data.append(dt_result)

  print(f"{n_result} clustered in {t_result} +/- {dt_result} seconds")
# Out:
# Trial 0 begins...
# Trial 0 complete: reading 8.256047859999967 seconds
# Trial 1 begins...
# Trial 1 complete: reading 8.256107713999995 seconds
# Trial 2 begins...
# Trial 2 complete: reading 7.184383951000086 seconds
# Trial 3 begins...
# Trial 3 complete: reading 7.320861743000023 seconds
# Trial 4 begins...
# Trial 4 complete: reading 7.57271558299999 seconds
# 168 clustered in 7.7180233702000125 +/- 0.5105457505288591 seconds
# Trial 0 begins...
# Trial 0 complete: reading 13.218365313999925 seconds
# Trial 1 begins...
# Trial 1 complete: reading 13.038426394999988 seconds
# Trial 2 begins...
# Trial 2 complete: reading 13.2394817899999 seconds
# Trial 3 begins...
# Trial 3 complete: reading 13.063327093999987 seconds
# Trial 4 begins...
# Trial 4 complete: reading 13.234826047999832 seconds
# 204 clustered in 13.158885328199926 +/- 0.099300531217421 seconds
# Trial 0 begins...
# Trial 0 complete: reading 25.24689524900009 seconds
# Trial 1 begins...
# Trial 1 complete: reading 25.108649816000025 seconds
# Trial 2 begins...
# Trial 2 complete: reading 25.17131657699997 seconds
# Trial 3 begins...
# Trial 3 complete: reading 25.24627360999989 seconds
# Trial 4 begins...
# Trial 4 complete: reading 25.38926295400006 seconds
# 253 clustered in 25.23247964120001 +/- 0.10494502909553782 seconds
# Trial 0 begins...
# Trial 0 complete: reading 49.57134270200004 seconds
# Trial 1 begins...
# Trial 1 complete: reading 50.138786069999924 seconds
# Trial 2 begins...
# Trial 2 complete: reading 50.729233928999975 seconds
# Trial 3 begins...
# Trial 3 complete: reading 49.882795257 seconds
# Trial 4 begins...
# Trial 4 complete: reading 52.27814060700007 seconds
# 317 clustered in 50.520059713 +/- 1.0707639594205058 seconds
# Trial 0 begins...
# Trial 0 complete: reading 104.52426578199993 seconds
# Trial 1 begins...
# Trial 1 complete: reading 104.36175206799999 seconds
# Trial 2 begins...
# Trial 2 complete: reading 104.18990551799993 seconds
# Trial 3 begins...
# Trial 3 complete: reading 104.49751925600003 seconds
# Trial 4 begins...
# Trial 4 complete: reading 104.46534414100006 seconds
# 398 clustered in 104.407757353 +/- 0.13649501792301044 seconds
# Trial 0 begins...
# Trial 0 complete: reading 204.818571109 seconds
# Trial 1 begins...
# Trial 1 complete: reading 204.8738570720002 seconds
# Trial 2 begins...
# Trial 2 complete: reading 206.92440037600045 seconds
# Trial 3 begins...
# Trial 3 complete: reading 203.04870831000017 seconds
# Trial 4 begins...
# Trial 4 complete: reading 203.97532696500002 seconds
# 498 clustered in 204.72817276640018 +/- 1.4352864828502276 seconds

# %%
def GhostJetPopulator_fastjet_version(jet_input, y_min, y_max, ny, phi_min, phi_max, nphi, epsil=1e-6, version=1):
  """
  Populates a set of input jets with ghosts jets. In particular, takes jet_input set,
  and adds a series of ny*nphi many ghost jets in a uniform (y,phi) grid.

  Parameters:
      jet_input (list): List of input jets.
      y_min, y_max (float): rapidity (y) bounds of the uniform (y,phi) grid where ghost jets are populated.
      phi_min, phi_max (float): phi-bounds of the uniform (y,phi) grid where ghost jets are populated.
      ny, nphi: number of ghost jets populated along y,phi axis respectively, resulting in N = ny*nphi many ghost jets.

      epsil (float): Energy of ghost jet, by default a soft, massless jet, with E = |p|= epsil.

      version (-1 or 1): alternating between versions of ghost jet indexing.

  Returns:
      list: List of input jets with added ghost jets.

  """

  y_axis = np.linspace(y_min, y_max, ny)
  phi_axis = np.linspace(phi_min, phi_max, nphi)


  y_grid, phi_grid = np.meshgrid(y_axis, phi_axis)

  y_phi_coordinates = np.column_stack((y_grid.ravel(), phi_grid.ravel()))

  # creating soft jets, using E = |p|= epsil,
  # and obtaining p-components through y, phi with
  # pz = E*tanh(y); pT = E**2 - pz**2,
  # px = pT*cos(phi); py = pT*sin(phi)

  pz_values = epsil * np.tanh(y_grid.ravel())
  pT_values = np.sqrt(epsil**2 - pz_values**2)
  px_values = pT_values * np.cos(phi_grid.ravel())
  py_values = pT_values * np.sin(phi_grid.ravel())

  #assigns indices to ghost jets sequentially, as len(jet_input), len(jet_input)+1, len(jet_input)+2, and so on.
  #input particles in jet_input assumed to be indexed as integers, from 0, 1, 2, ..., len(jet_input)-1.

  if version == 1:
    ghost_jets = [fastjet.PseudoJet(px, py, pz, epsil) for i, (px, py, pz) in enumerate(zip(px_values.ravel(), py_values.ravel(), pz_values.ravel()))]
    # for gj in ghost_jets:
    #     print(gj)
  elif version == -1:
    ghost_jets = [fastjet.PseudoJet(px, py, pz, epsil) for i, (px, py, pz) in enumerate(zip(px_values.ravel(), py_values.ravel(), pz_values.ravel()))]
  else:
    raise ValueError("Invalid version value. Must be -1 or 1.")
  #alternate possibility: index as negative numbers [i+len(jet_input)] --> [-(i+1)] (as i starts at 0), so one can more easily distinguish ghost jets by index


  jet_input += ghost_jets

  return jet_input

  jet_input += ghost_jets

  return jet_input

#!!!! key edit: on ghost_jets lines; needed to change "fastjet.PseudoJet(px,py,pz,E)" -> "fastjet.PseudoJet(px,py,pz,epsil)"

# %%
antikt_jetdef = fastjet.JetDefinition(fastjet.antikt_algorithm, 0.4)

# %%
def do_fj_clustering(inputjetset, jetdef):
    _cluster = fastjet.ClusterSequence(inputjetset, jetdef)

# %%
N_fj_data = []
t_fj_data = []
dt_fj_data = []

runcount = len(nlist)

#just comparing antikt:

for _n in nlist:

  InputJetsGhosted_fj = GhostJetPopulator_fastjet_version(InputJets_fj, ymin, ymax, _n, 0, 2*pi, _n)
    
  n_result, t_result, dt_result = TimingMeasurement(InputJetsGhosted_fj, do_fj_clustering, inputjetset=InputJetsGhosted_fj, jetdef=antikt_jetdef)

  N_fj_data.append(n_result)
  t_fj_data.append(t_result)
  dt_fj_data.append(dt_result)

  print(f"{n_result} clustered in {t_result} +/- {dt_result} seconds")
# Out:
# Trial 0 begins...
# Trial 0 complete: reading 0.0006047280003258493 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.0001836359997469117 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.00015955099979692022 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.00014984500012360513 seconds
# Trial 4 begins...
# Trial 4 complete: reading 0.00014783400001761038 seconds
# 168 clustered in 0.00024911880000217935 +/- 0.00019930014385843143 seconds
# Trial 0 begins...
# Trial 0 complete: reading 0.0002507450003577105 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.00019009900006494718 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.00019936099988626665 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.0001803709997147962 seconds
# Trial 4 begins...
# Trial 4 complete: reading 0.0001948049998645729 seconds
# 204 clustered in 0.00020307619997765868 +/- 2.75611312778258e-05 seconds
# Trial 0 begins...
# Trial 0 complete: reading 0.0003158370000164723 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.000243101999785722 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.00023258400005943258 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.00022710800021741306 seconds
# Trial 4 begins...
# Trial 4 complete: reading 0.00022564199980479316 seconds
# 253 clustered in 0.00024885459997676663 +/- 3.806640958096961e-05 seconds
# Trial 0 begins...
# Trial 0 complete: reading 0.0004204639999443316 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.00042420599993420183 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.0003636800001913798 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.00035434600022199447 seconds
# Trial 4 begins...
# Trial 4 complete: reading 0.0003823009997176996 seconds
# 317 clustered in 0.00038899940000192146 +/- 3.207929401408611e-05 seconds
# Trial 0 begins...
# Trial 0 complete: reading 0.0006049690000509145 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.0004884139998466708 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.0004454039999473025 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.000557967000077042 seconds
# Trial 4 begins...
# #--------------------------------------------------------------------------
# #                         FastJet release 3.5.1
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           https://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# Trial 4 complete: reading 0.0014159969996399013 seconds
# 398 clustered in 0.0007025501999123662 +/- 0.00040355024737247144 seconds
# Trial 0 begins...
# Trial 0 complete: reading 0.0009608509999452508 seconds
# Trial 1 begins...
# Trial 1 complete: reading 0.0008243769998443895 seconds
# Trial 2 begins...
# Trial 2 complete: reading 0.0009621379999771307 seconds
# Trial 3 begins...
# Trial 3 complete: reading 0.0006573249997927633 seconds
# Trial 4 begins...
# Trial 4 complete: reading 0.0007113009996828623 seconds
# 498 clustered in 0.0008231983998484793 +/- 0.0001399007263250708 seconds

# %%
len(InputJets) == len(InputJets_fj)
# Out:
# True

# %%
import pandas as pd

tvNdf = pd.DataFrame({
    "t": t_data,
    "dt": dt_data,
    "N": N_data
})

tvNdf.to_csv('timing_data_naive.csv')

tvNdf_fj = pd.DataFrame({
    "t": t_fj_data,
    "dt": dt_fj_data,
    "N": N_fj_data
})

tvNdf.to_csv('timing_data_fj.csv')

# %%
import matplotlib.pyplot as plt

plt.errorbar(N_data,t_data,yerr=dt_data,fmt="o",label="Naive")
plt.errorbar(N_fj_data,t_fj_data,yerr=dt_fj_data,fmt="o",label="FJ")
plt.xlabel("N")
plt.ylabel("Time Elapsed [s]")
plt.legend()
plt.show()

# %%
#plot fastjet data separately, to avoid flattenning graph and making its patterns more visible upon inspection

plt.errorbar(N_fj_data,t_fj_data,yerr=dt_fj_data,fmt="o",label="FJ")
plt.xlabel("N")
plt.ylabel("Time Elapsed [s]")
plt.legend()
plt.show()

# %%
plt.errorbar(N_data,t_data,yerr=dt_data,fmt="o",label="Naive")
plt.xlabel("N")
plt.ylabel("Time Elapsed [s]")
plt.legend()
plt.show()
