# %%
# !pip install uproot
# Out:
# Collecting uproot
#   Downloading uproot-5.7.4-py3-none-any.whl.metadata (35 kB)
# Collecting awkward>=2.8.2 (from uproot)
#   Downloading awkward-2.9.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: cramjam>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from uproot) (2.11.0)
# Requirement already satisfied: fsspec!=2026.2.0 in /usr/local/lib/python3.12/dist-packages (from uproot) (2025.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from uproot) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from uproot) (26.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from uproot) (3.7.0)
# Collecting awkward-cpp==53 (from awkward>=2.8.2->uproot)
#   Downloading awkward_cpp-53-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Downloading uproot-5.7.4-py3-none-any.whl (397 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.5/397.5 kB 10.8 MB/s eta 0:00:00
# Downloading awkward-2.9.1-py3-none-any.whl (924 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 924.2/924.2 kB 31.2 MB/s eta 0:00:00
# Downloading awkward_cpp-53-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (657 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.8/657.8 kB 42.0 MB/s eta 0:00:00
# Installing collected packages: awkward-cpp, awkward, uproot
# Successfully installed awkward-2.9.1 awkward-cpp-53 uproot-5.7.4

# %%
import naive

# %%
InputJets = naive.JetReader("PythiaEventsBatchTest.root",'pdEventTree')

# %%
OutHistory_kT, OutJets_kT = naive.gen_clustering(1, InputJets,0.4)
OutHistory_CA, OutJets_CA = naive.gen_clustering(0, InputJets,0.4)
OutHistory_antikT, OutJets_antikT = naive.gen_clustering(-1, InputJets,0.4)

# %%
naive.JetWriter("naive_antikt.root",OutJets_antikT,"finalJets")
naive.JetWriter("naive_kt.root",OutJets_kT,"finalJets")
naive.JetWriter("naive_ca.root",OutJets_CA,"finalJets")

# %%
print("antikt:")
for x in OutHistory_antikT:
  print(f"{x[0]}: {x[1]}")
# Out:
# antikt:
# merge: ([132], [117])
# merge: ([122], [120])
# merge: ([116], [48])
# merge: ([136], [35])
# merge: ([95], [23])
# merge: ([128], [123])
# merge: ([140], [13])
# merge: ([142], [124])
# merge: ([46], [10])
# merge: ([79], [28])
# merge: ([92], [62])
# merge: ([89], [57])
# merge: ([86], [20])
# merge: ([139], [14])
# merge: ([118], [65])
# merge: ([73], [72])
# merge: ([137], [88])
# merge: ([125], [99])
# merge: ([94], [82])
# merge: ([110], [56])
# merge: ([116, 48], [55])
# merge: ([101], [98])
# merge: ([132, 117], [64])
# merge: ([91], [78])
# merge: ([127], [109])
# merge: ([115], [34])
# merge: ([113], [59])
# merge: ([32], [3])
# merge: ([92, 62], [114])
# merge: ([63], [61])
# merge: ([97], [87])
# merge: ([30], [8])
# merge: ([76], [74])
# merge: ([68], [47])
# merge: ([134], [96])
# merge: ([116, 48, 55], [118, 65])
# merge: ([67], [49])
# merge: ([85], [11])
# merge: ([66], [37])
# merge: ([131], [26])
# merge: ([138], [60])
# merge: ([110, 56], [40])
# merge: ([104], [70])
# merge: ([77], [75])
# merge: ([81], [4])
# merge: ([104, 70], [71])
# merge: ([141], [19])
# merge: ([91, 78], [7])
# merge: ([17], [15])
# merge: ([130], [90])
# merge: ([107], [106])
# final: [76, 74]
# merge: ([94, 82], [133])
# merge: ([89, 57], [42])
# merge: ([127, 109], [108])
# merge: ([131, 26], [43])
# merge: ([121], [54])
# merge: ([66, 37], [128, 123])
# merge: ([101, 98], [102])
# merge: ([58], [9])
# merge: ([116, 48, 55, 118, 65], [52])
# merge: ([38], [0])
# merge: ([30, 8], [80])
# merge: ([104, 70, 71], [105])
# merge: ([85, 11], [84])
# merge: ([141, 19], [21])
# final: [77, 75]
# merge: ([67, 49], [129])
# merge: ([86, 20], [122, 120])
# merge: ([135], [18])
# merge: ([32, 3], [83])
# merge: ([91, 78, 7], [112])
# merge: ([130, 90], [29])
# merge: ([115, 34], [73, 72])
# merge: ([119], [12])
# final: [66, 37, 128, 123]
# merge: ([140, 13], [53])
# merge: ([94, 82, 133], [46, 10])
# final: [94, 82, 133, 46, 10]
# merge: ([89, 57, 42], [27])
# merge: ([17, 15], [125, 99])
# merge: ([68, 47], [50])
# final: [68, 47, 50]
# merge: ([138, 60], [93])
# merge: ([113, 59], [5])
# merge: ([115, 34, 73, 72], [33])
# merge: ([38, 0], [126])
# final: [115, 34, 73, 72, 33]
# merge: ([30, 8, 80], [81, 4])
# final: [30, 8, 80, 81, 4]
# final: [16]
# final: [111]
# merge: ([92, 62, 114], [24])
# merge: ([139, 14], [100])
# merge: ([17, 15, 125, 99], [142, 124])
# final: [38, 0, 126]
# final: [116, 48, 55, 118, 65, 52]
# final: [17, 15, 125, 99, 142, 124]
# final: [119, 12]
# merge: ([134, 96], [97, 87])
# final: [139, 14, 100]
# merge: ([141, 19, 21], [51])
# final: [141, 19, 21, 51]
# final: [85, 11, 84]
# merge: ([127, 109, 108], [39])
# merge: ([132, 117, 64], [69])
# final: [132, 117, 64, 69]
# final: [138, 60, 93]
# final: [135, 18]
# final: [110, 56, 40]
# final: [134, 96, 97, 87]
# final: [131, 26, 43]
# merge: ([86, 20, 122, 120], [22])
# final: [86, 20, 122, 120, 22]
# merge: ([58, 9], [44])
# final: [58, 9, 44]
# final: [107, 106]
# final: [113, 59, 5]
# final: [32, 3, 83]
# final: [140, 13, 53]
# final: [89, 57, 42, 27]
# final: [25]
# final: [63, 61]
# final: [130, 90, 29]
# merge: ([95, 23], [136, 35])
# final: [95, 23, 136, 35]
# final: [104, 70, 71, 105]
# final: [92, 62, 114, 24]
# final: [67, 49, 129]
# final: [31]
# final: [137, 88]
# final: [79, 28]
# final: [2]
# merge: ([36], [1])
# final: [36, 1]
# final: [91, 78, 7, 112]
# final: [45]
# final: [121, 54]
# final: [127, 109, 108, 39]
# final: [41]
# final: [6]
# final: [101, 98, 102]
# final: [103]

# %%
print("kt:")
for x in OutHistory_kT:
  print(f"{x[0]}: {x[1]}")
# Out:
# kt:
# merge: ([132], [117])
# merge: ([122], [120])
# merge: ([116], [48])
# final: [136]
# final: [95]
# merge: ([128], [123])
# merge: ([140], [13])
# final: [142]
# final: [92]
# merge: ([46], [10])
# final: [118]
# merge: ([79], [28])
# merge: ([89], [57])
# final: [86]
# final: [125]
# merge: ([139], [14])
# final: [101]
# final: [65]
# final: [82]
# merge: ([73], [72])
# final: [59]
# merge: ([137], [88])
# final: [127]
# merge: ([110], [56])
# merge: ([116, 48], [55])
# final: [114]
# merge: ([132, 117], [64])
# final: [7]
# final: [98]
# final: [91]
# final: [49]
# merge: ([115], [34])
# final: [107]
# merge: ([32], [3])
# merge: ([63], [61])
# merge: ([97], [87])
# final: [112]
# merge: ([30], [8])
# merge: ([76], [74])
# final: [108]
# merge: ([68], [47])
# final: [130]
# final: [71]
# final: [134]
# final: [37]
# final: [81]
# merge: ([85], [11])
# merge: ([131], [26])
# merge: ([138], [60])
# merge: ([110, 56], [40])
# final: [105]
# merge: ([104], [70])
# merge: ([77], [75])
# final: [84]
# merge: ([141], [19])
# merge: ([129], [67])
# final: [38]
# merge: ([17], [15])
# final: [109]
# final: [39]
# final: [43]
# final: [124]
# final: [133]
# final: [58]
# final: [27]
# final: [33]
# final: [121]
# final: [54]
# final: [42]
# final: [103]
# merge: ([128, 123], [66])
# merge: ([137, 88], [78])
# final: [135]
# final: [113]
# final: [83]
# final: [62]
# final: [22]
# final: [53]
# merge: ([90], [29])
# final: [102]
# final: [97, 87]
# final: [89, 57]
# final: [21]
# merge: ([116, 48, 55], [52])
# final: [99]
# final: [24]
# final: [119]
# merge: ([122, 120], [20])
# merge: ([30, 8], [80])
# final: [4]
# final: [50]
# final: [126]
# merge: ([46, 10], [94])
# final: [100]
# merge: ([115, 34], [73, 72])
# final: [1]
# final: [6]
# final: [41]
# final: [44]
# final: [93]
# final: [138, 60]
# final: [45]
# final: [36]
# final: [104, 70]
# final: [5]
# final: [9]
# final: [140, 13]
# final: [23]
# final: [32, 3]
# final: [69]
# final: [96]
# final: [132, 117, 64]
# final: [129, 67]
# final: [2]
# final: [35]
# final: [79, 28]
# final: [90, 29]
# final: [139, 14]
# final: [0]
# merge: ([141, 19], [51])
# merge: ([77, 75], [76, 74])
# final: [18]
# final: [31]
# final: [131, 26]
# final: [17, 15]
# merge: ([111], [25])
# final: [63, 61]
# final: [106]
# final: [122, 120, 20]
# final: [12]
# final: [110, 56, 40]
# final: [137, 88, 78]
# final: [85, 11]
# final: [30, 8, 80]
# final: [115, 34, 73, 72]
# final: [116, 48, 55, 52]
# final: [68, 47]
# final: [16]
# final: [141, 19, 51]
# final: [46, 10, 94]
# final: [128, 123, 66]
# final: [111, 25]
# final: [77, 75, 76, 74]

# %%
print("ca:")
for x in OutHistory_CA:
  print(f"{x[0]}: {x[1]}")
# Out:
# ca:
# merge: ([132], [117])
# merge: ([122], [120])
# merge: ([116], [48])
# merge: ([136], [35])
# merge: ([95], [23])
# merge: ([128], [123])
# merge: ([140], [13])
# merge: ([142], [124])
# merge: ([46], [10])
# merge: ([79], [28])
# merge: ([92], [62])
# merge: ([89], [57])
# merge: ([86], [20])
# merge: ([139], [14])
# merge: ([118], [65])
# merge: ([73], [72])
# merge: ([137], [88])
# merge: ([125], [99])
# merge: ([94], [82])
# merge: ([110], [56])
# merge: ([116, 48], [55])
# merge: ([101], [98])
# merge: ([132, 117], [64])
# merge: ([91], [78])
# merge: ([127], [109])
# merge: ([115], [34])
# merge: ([113], [59])
# merge: ([32], [3])
# merge: ([92, 62], [114])
# merge: ([63], [61])
# merge: ([97], [87])
# merge: ([30], [8])
# merge: ([76], [74])
# merge: ([68], [47])
# merge: ([134], [96])
# merge: ([116, 48, 55], [118, 65])
# merge: ([67], [49])
# merge: ([85], [11])
# merge: ([66], [37])
# merge: ([131], [26])
# merge: ([138], [60])
# merge: ([110, 56], [40])
# merge: ([104], [70])
# merge: ([77], [75])
# merge: ([81], [4])
# merge: ([104, 70], [71])
# merge: ([141], [19])
# merge: ([91, 78], [7])
# merge: ([17], [15])
# merge: ([130], [90])
# merge: ([107], [106])
# merge: ([94, 82], [133])
# merge: ([89, 57], [42])
# merge: ([127, 109], [108])
# merge: ([131, 26], [43])
# merge: ([121], [54])
# merge: ([66, 37], [128, 123])
# merge: ([101, 98], [102])
# merge: ([58], [9])
# merge: ([116, 48, 55, 118, 65], [52])
# merge: ([38], [0])
# merge: ([30, 8], [80])
# merge: ([104, 70, 71], [105])
# merge: ([85, 11], [84])
# merge: ([141, 19], [21])
# merge: ([67, 49], [129])
# merge: ([86, 20], [122, 120])
# merge: ([135], [18])
# merge: ([32, 3], [83])
# merge: ([91, 78, 7], [112])
# merge: ([130, 90], [29])
# merge: ([115, 34], [73, 72])
# merge: ([119], [12])
# merge: ([140, 13], [53])
# merge: ([94, 82, 133], [46, 10])
# merge: ([89, 57, 42], [27])
# merge: ([17, 15], [125, 99])
# merge: ([66, 37, 128, 123], [22])
# merge: ([68, 47], [50])
# merge: ([138, 60], [93])
# merge: ([113, 59], [5])
# merge: ([115, 34, 73, 72], [33])
# merge: ([38, 0], [126])
# merge: ([30, 8, 80], [81, 4])
# merge: ([77, 75], [76, 74])
# merge: ([92, 62, 114], [24])
# merge: ([139, 14], [100])
# merge: ([17, 15, 125, 99], [142, 124])
# merge: ([111], [25])
# merge: ([77, 75, 76, 74], [1])
# merge: ([134, 96], [97, 87])
# merge: ([141, 19, 21], [51])
# merge: ([127, 109, 108], [39])
# merge: ([132, 117, 64], [69])
# final: [2]
# final: [6]
# final: [16]
# final: [31]
# final: [36]
# final: [41]
# final: [44]
# final: [45]
# final: [103]
# final: [136, 35]
# final: [95, 23]
# final: [79, 28]
# final: [137, 88]
# final: [63, 61]
# final: [110, 56, 40]
# final: [107, 106]
# final: [131, 26, 43]
# final: [121, 54]
# final: [101, 98, 102]
# final: [58, 9]
# final: [116, 48, 55, 118, 65, 52]
# final: [104, 70, 71, 105]
# final: [85, 11, 84]
# final: [67, 49, 129]
# final: [86, 20, 122, 120]
# final: [135, 18]
# final: [32, 3, 83]
# final: [91, 78, 7, 112]
# final: [130, 90, 29]
# final: [119, 12]
# final: [140, 13, 53]
# final: [94, 82, 133, 46, 10]
# final: [89, 57, 42, 27]
# final: [66, 37, 128, 123, 22]
# final: [68, 47, 50]
# final: [138, 60, 93]
# final: [113, 59, 5]
# final: [115, 34, 73, 72, 33]
# final: [38, 0, 126]
# final: [30, 8, 80, 81, 4]
# final: [92, 62, 114, 24]
# final: [139, 14, 100]
# final: [17, 15, 125, 99, 142, 124]
# final: [111, 25]
# final: [77, 75, 76, 74, 1]
# final: [134, 96, 97, 87]
# final: [141, 19, 21, 51]
# final: [127, 109, 108, 39]
# final: [132, 117, 64, 69]
