# %%
# !pip install uproot
# Out:
# Collecting uproot
#   Downloading uproot-5.7.4-py3-none-any.whl.metadata (35 kB)
# Collecting awkward>=2.8.2 (from uproot)
#   Downloading awkward-2.9.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: cramjam>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from uproot) (2.11.0)
# Requirement already satisfied: fsspec!=2026.2.0 in /usr/local/lib/python3.12/dist-packages (from uproot) (2025.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from uproot) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from uproot) (26.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from uproot) (3.7.0)
# Collecting awkward-cpp==53 (from awkward>=2.8.2->uproot)
#   Downloading awkward_cpp-53-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Downloading uproot-5.7.4-py3-none-any.whl (397 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.5/397.5 kB 12.6 MB/s eta 0:00:00
# Downloading awkward-2.9.1-py3-none-any.whl (924 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 924.2/924.2 kB 20.4 MB/s eta 0:00:00
# Downloading awkward_cpp-53-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (657 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.8/657.8 kB 33.2 MB/s eta 0:00:00
# Installing collected packages: awkward-cpp, awkward, uproot
# Successfully installed awkward-2.9.1 awkward-cpp-53 uproot-5.7.4

# %%
import naive

# %%
InputJets = naive.JetReader("PythiaEventsBatchTest.root",'pdEventTree')

# %%
OutHistory_kT, OutJets_kT = naive.gen_clustering(1, InputJets,0.4)
OutHistory_CA, OutJets_CA = naive.gen_clustering(0, InputJets,0.4)
OutHistory_antikT, OutJets_antikT = naive.gen_clustering(-1, InputJets,0.4)

# %%
naive.JetWriter("naive_antikt.root",OutJets_antikT,"finalJets")
naive.JetWriter("naive_kt.root",OutJets_kT,"finalJets")
naive.JetWriter("naive_ca.root",OutJets_CA,"finalJets")

# %%
print("antikt:")
for x in OutHistory_antikT:
  print(f"{x[0]}: {x[1]}")
# Out:
# antikt:
# merge: ([120], [86])
# merge: ([132], [117])
# merge: ([116], [48])
# merge: ([118], [65])
# merge: ([136], [35])
# merge: ([95], [23])
# merge: ([140], [13])
# merge: ([59], [27])
# merge: ([142], [124])
# merge: ([79], [28])
# merge: ([92], [24])
# merge: ([120, 86], [122])
# merge: ([137], [88])
# merge: ([128], [123])
# merge: ([125], [15])
# merge: ([71], [38])
# merge: ([101], [98])
# merge: ([73], [72])
# merge: ([94], [82])
# merge: ([59, 27], [89])
# merge: ([116, 48], [55])
# merge: ([110], [56])
# merge: ([131], [26])
# merge: ([63], [61])
# merge: ([91], [78])
# merge: ([139], [100])
# merge: ([132, 117], [64])
# merge: ([46], [10])
# merge: ([114], [62])
# merge: ([115], [34])
# merge: ([97], [87])
# merge: ([67], [49])
# merge: ([118, 65], [84])
# merge: ([76], [74])
# merge: ([134], [96])
# merge: ([37], [22])
# merge: ([21], [19])
# merge: ([91, 78], [7])
# merge: ([32], [3])
# merge: ([85], [11])
# merge: ([110, 56], [40])
# merge: ([68], [47])
# merge: ([104], [70])
# merge: ([77], [75])
# merge: ([30], [8])
# merge: ([81], [4])
# merge: ([138], [60])
# merge: ([130], [90])
# merge: ([141], [51])
# merge: ([127], [109])
# merge: ([101, 98], [102])
# merge: ([107], [106])
# merge: ([128, 123], [66])
# merge: ([121], [54])
# merge: ([131, 26], [43])
# merge: ([94, 82], [133])
# final: [76, 74]
# merge: ([58], [9])
# merge: ([108], [39])
# merge: ([125, 15], [17])
# merge: ([139, 100], [14])
# merge: ([104, 70], [105])
# merge: ([138, 60], [29])
# merge: ([32, 3], [83])
# merge: ([67, 49], [129])
# merge: ([91, 78, 7], [112])
# merge: ([135], [18])
# final: [77, 75]
# merge: ([30, 8], [80])
# merge: ([59, 27, 89], [57])
# merge: ([120, 86, 122], [20])
# merge: ([94, 82, 133], [46, 10])
# merge: ([113], [5])
# merge: ([73, 72], [33])
# merge: ([138, 60, 29], [93])
# merge: ([119], [12])
# merge: ([63, 61], [31])
# final: [94, 82, 133, 46, 10]
# merge: ([125, 15, 17], [99])
# merge: ([111], [25])
# final: [111, 25]
# merge: ([140, 13], [53])
# merge: ([104, 70, 105], [71, 38])
# final: [128, 123, 66]
# final: [63, 61, 31]
# merge: ([118, 65, 84], [69])
# merge: ([68, 47], [50])
# final: [68, 47, 50]
# merge: ([126], [0])
# merge: ([116, 48, 55], [52])
# merge: ([30, 8, 80], [81, 4])
# final: [30, 8, 80, 81, 4]
# final: [16]
# merge: ([125, 15, 17, 99], [142, 124])
# final: [138, 60, 29, 93]
# merge: ([114, 62], [92, 24])
# final: [125, 15, 17, 99, 142, 124]
# final: [119, 12]
# final: [116, 48, 55, 52]
# final: [139, 100, 14]
# merge: ([121, 54], [97, 87])
# merge: ([59, 27, 89, 57], [42])
# merge: ([108, 39], [127, 109])
# final: [126, 0]
# final: [141, 51]
# merge: ([115, 34], [36])
# final: [115, 34, 36]
# final: [85, 11]
# final: [135, 18]
# final: [110, 56, 40]
# final: [104, 70, 105, 71, 38]
# merge: ([58, 9], [44])
# final: [58, 9, 44]
# final: [131, 26, 43]
# final: [107, 106]
# final: [120, 86, 122, 20]
# final: [59, 27, 89, 57, 42]
# merge: ([118, 65, 84, 69], [1])
# final: [118, 65, 84, 69, 1]
# final: [32, 3, 83]
# final: [140, 13, 53]
# final: [121, 54, 97, 87]
# final: [113, 5]
# final: [21, 19]
# merge: ([91, 78, 7, 112], [137, 88])
# final: [91, 78, 7, 112, 137, 88]
# merge: ([95, 23], [136, 35])
# final: [95, 23, 136, 35]
# final: [114, 62, 92, 24]
# final: [67, 49, 129]
# final: [134, 96]
# final: [73, 72, 33]
# final: [79, 28]
# final: [2]
# final: [132, 117, 64]
# final: [45]
# final: [108, 39, 127, 109]
# final: [41]
# final: [6]
# final: [130, 90]
# final: [37, 22]
# final: [101, 98, 102]
# final: [103]

# %%
print("kt:")
for x in OutHistory_kT:
  print(f"{x[0]}: {x[1]}")
# Out:
# kt:
# merge: ([120], [86])
# merge: ([132], [117])
# merge: ([116], [48])
# final: [136]
# final: [95]
# merge: ([118], [65])
# merge: ([140], [13])
# final: [142]
# final: [92]
# merge: ([59], [27])
# merge: ([79], [28])
# merge: ([120, 86], [122])
# merge: ([137], [88])
# merge: ([128], [123])
# final: [125]
# merge: ([71], [38])
# final: [101]
# final: [82]
# merge: ([73], [72])
# final: [127]
# merge: ([59, 27], [89])
# merge: ([116, 48], [55])
# final: [114]
# merge: ([110], [56])
# final: [7]
# merge: ([131], [26])
# final: [118, 65]
# final: [98]
# merge: ([63], [61])
# final: [139]
# final: [91]
# merge: ([94], [46])
# merge: ([132, 117], [64])
# final: [49]
# final: [107]
# merge: ([115], [34])
# merge: ([97], [87])
# final: [112]
# merge: ([76], [74])
# merge: ([134], [96])
# final: [108]
# final: [130]
# merge: ([37], [22])
# merge: ([21], [19])
# final: [81]
# merge: ([32], [3])
# merge: ([85], [11])
# merge: ([110, 56], [40])
# final: [105]
# merge: ([68], [47])
# merge: ([104], [70])
# merge: ([77], [75])
# final: [84]
# merge: ([30], [8])
# merge: ([129], [67])
# merge: ([138], [60])
# merge: ([141], [51])
# final: [109]
# final: [39]
# final: [43]
# final: [124]
# final: [15]
# final: [133]
# final: [57]
# merge: ([128, 123], [66])
# final: [58]
# final: [33]
# final: [121]
# final: [54]
# final: [42]
# final: [103]
# merge: ([94, 46], [10])
# merge: ([100], [14])
# final: [135]
# final: [113]
# final: [83]
# final: [78]
# final: [62]
# final: [53]
# final: [102]
# final: [97, 87]
# final: [90]
# final: [71, 38]
# final: [29]
# final: [99]
# final: [24]
# final: [119]
# final: [59, 27, 89]
# final: [4]
# final: [50]
# final: [80]
# final: [126]
# final: [120, 86, 122]
# final: [37, 22]
# final: [20]
# final: [73, 72]
# final: [1]
# final: [6]
# final: [41]
# final: [44]
# final: [93]
# merge: ([63, 61], [31])
# final: [138, 60]
# final: [45]
# final: [36]
# final: [17]
# final: [104, 70]
# final: [5]
# merge: ([111], [25])
# final: [9]
# final: [140, 13]
# final: [116, 48, 55]
# final: [23]
# final: [32, 3]
# final: [69]
# final: [132, 117, 64]
# final: [52]
# final: [129, 67]
# final: [2]
# final: [35]
# final: [79, 28]
# final: [137, 88]
# final: [0]
# merge: ([77, 75], [76, 74])
# final: [18]
# final: [115, 34]
# final: [131, 26]
# final: [30, 8]
# final: [134, 96]
# final: [106]
# final: [21, 19]
# final: [12]
# final: [110, 56, 40]
# final: [85, 11]
# final: [100, 14]
# final: [141, 51]
# final: [68, 47]
# final: [16]
# final: [63, 61, 31]
# final: [94, 46, 10]
# final: [128, 123, 66]
# final: [111, 25]
# final: [77, 75, 76, 74]

# %%
print("ca:")
for x in OutHistory_CA:
  print(f"{x[0]}: {x[1]}")
# Out:
# ca:
# merge: ([120], [86])
# merge: ([132], [117])
# merge: ([116], [48])
# merge: ([118], [65])
# merge: ([136], [35])
# merge: ([95], [23])
# merge: ([140], [13])
# merge: ([59], [27])
# merge: ([142], [124])
# merge: ([79], [28])
# merge: ([92], [24])
# merge: ([120, 86], [122])
# merge: ([137], [88])
# merge: ([128], [123])
# merge: ([125], [15])
# merge: ([71], [38])
# merge: ([101], [98])
# merge: ([73], [72])
# merge: ([94], [82])
# merge: ([59, 27], [89])
# merge: ([116, 48], [55])
# merge: ([110], [56])
# merge: ([131], [26])
# merge: ([63], [61])
# merge: ([91], [78])
# merge: ([139], [100])
# merge: ([132, 117], [64])
# merge: ([46], [10])
# merge: ([114], [62])
# merge: ([115], [34])
# merge: ([97], [87])
# merge: ([67], [49])
# merge: ([118, 65], [84])
# merge: ([76], [74])
# merge: ([134], [96])
# merge: ([37], [22])
# merge: ([21], [19])
# merge: ([91, 78], [7])
# merge: ([32], [3])
# merge: ([85], [11])
# merge: ([110, 56], [40])
# merge: ([68], [47])
# merge: ([104], [70])
# merge: ([77], [75])
# merge: ([30], [8])
# merge: ([81], [4])
# merge: ([138], [60])
# merge: ([130], [90])
# merge: ([141], [51])
# merge: ([127], [109])
# merge: ([101, 98], [102])
# merge: ([107], [106])
# merge: ([128, 123], [66])
# merge: ([121], [54])
# merge: ([131, 26], [43])
# merge: ([94, 82], [133])
# merge: ([58], [9])
# merge: ([108], [39])
# merge: ([125, 15], [17])
# merge: ([139, 100], [14])
# merge: ([104, 70], [105])
# merge: ([138, 60], [29])
# merge: ([32, 3], [83])
# merge: ([67, 49], [129])
# merge: ([91, 78, 7], [112])
# merge: ([135], [18])
# merge: ([30, 8], [80])
# merge: ([59, 27, 89], [57])
# merge: ([120, 86, 122], [20])
# merge: ([94, 82, 133], [46, 10])
# merge: ([113], [5])
# merge: ([73, 72], [33])
# merge: ([138, 60, 29], [93])
# merge: ([119], [12])
# merge: ([63, 61], [31])
# merge: ([125, 15, 17], [99])
# merge: ([111], [25])
# merge: ([140, 13], [53])
# merge: ([104, 70, 105], [71, 38])
# merge: ([118, 65, 84], [69])
# merge: ([68, 47], [50])
# merge: ([126], [0])
# merge: ([116, 48, 55], [52])
# merge: ([30, 8, 80], [81, 4])
# merge: ([77, 75], [76, 74])
# merge: ([125, 15, 17, 99], [142, 124])
# merge: ([114, 62], [92, 24])
# merge: ([77, 75, 76, 74], [1])
# merge: ([128, 123, 66], [37, 22])
# merge: ([121, 54], [97, 87])
# merge: ([59, 27, 89, 57], [42])
# merge: ([108, 39], [127, 109])
# merge: ([115, 34], [36])
# final: [2]
# final: [6]
# final: [16]
# final: [41]
# final: [44]
# final: [45]
# final: [103]
# final: [136, 35]
# final: [95, 23]
# final: [79, 28]
# final: [137, 88]
# final: [132, 117, 64]
# final: [134, 96]
# final: [21, 19]
# final: [85, 11]
# final: [110, 56, 40]
# final: [130, 90]
# final: [141, 51]
# final: [101, 98, 102]
# final: [107, 106]
# final: [131, 26, 43]
# final: [58, 9]
# final: [139, 100, 14]
# final: [32, 3, 83]
# final: [67, 49, 129]
# final: [91, 78, 7, 112]
# final: [135, 18]
# final: [120, 86, 122, 20]
# final: [94, 82, 133, 46, 10]
# final: [113, 5]
# final: [73, 72, 33]
# final: [138, 60, 29, 93]
# final: [119, 12]
# final: [63, 61, 31]
# final: [111, 25]
# final: [140, 13, 53]
# final: [104, 70, 105, 71, 38]
# final: [118, 65, 84, 69]
# final: [68, 47, 50]
# final: [126, 0]
# final: [116, 48, 55, 52]
# final: [30, 8, 80, 81, 4]
# final: [125, 15, 17, 99, 142, 124]
# final: [114, 62, 92, 24]
# final: [77, 75, 76, 74, 1]
# final: [128, 123, 66, 37, 22]
# final: [121, 54, 97, 87]
# final: [59, 27, 89, 57, 42]
# final: [108, 39, 127, 109]
# final: [115, 34, 36]
